# %% [markdown]
# # Unit 4 — Notebook 2: Agentic Workflows
# ## Introduction, Design Patterns, AutoGen & CrewAI
#
# ---
#
# ### What you will learn
#
# | Section | Topic |
# |---|---|
# | 1 | What is Agentic AI? The ReAct loop explained |
# | 2 | Agentic Design Patterns (Reflection, Planning, Tool Use, Multi-Agent) |
# | 3 | AutoGen — Microsoft's conversational agent framework |
# | 4 | CrewAI — Role-based multi-agent orchestration |
# | 5 | Devyan — A full 4-agent software development pipeline |
#
# ### Why Agentic AI?
#
# Standard LLM usage follows a **request–response** pattern:
#
# ```
# User → [Single Prompt] → LLM → [Single Response] → Done
# ```
#
# This works for simple tasks. But real-world tasks require:
# - **Planning** — breaking a goal into steps
# - **Tool use** — calling APIs, searching the web, writing files
# - **Memory** — remembering what happened in previous steps
# - **Error recovery** — retrying when a step fails
# - **Collaboration** — multiple specialized agents working together
#
# **Agentic AI** gives LLMs a loop: the ability to think → act → observe → think again.
#
# ```
# AGENTIC LOOP (ReAct Pattern)
# ─────────────────────────────────────
#          ┌──────────────────┐
#          │    GOAL / TASK   │
#          └────────┬─────────┘
#                   │
#          ┌────────▼─────────┐
#     ┌───►│    THINK (LLM)   │  "What should I do next?"
#     │    └────────┬─────────┘
#     │             │
#     │    ┌────────▼─────────┐
#     │    │    ACT (Tool)    │  Search / Write / Call API
#     │    └────────┬─────────┘
#     │             │
#     │    ┌────────▼─────────┐
#     └────│  OBSERVE (Result)│  "What did I get back?"
#          └────────┬─────────┘
#                   │
#          ┌────────▼─────────┐
#          │  GOAL REACHED?   │  If yes → Output. If no → loop.
#          └──────────────────┘
# ```

# %% [markdown]
# ## Setup

# %%
# pyautogen>=0.4 renamed the module to autogen_agentchat — pin to <0.4 for
# the classic ConversableAgent API used in this notebook.
# litellm is required by CrewAI to route to Groq (or any non-native provider).
# crewai checks for litellm at IMPORT TIME — if crewai was already imported
# before litellm was installed, you must restart the kernel for the check to pass.
# %pip install -q "pyautogen<0.4" tavily-python crewai crewai-tools litellm python-dotenv

print("")
print("*** IMPORTANT: Restart the kernel now before running any other cell. ***")
print("    Kernel -> Restart Kernel  (or the restart button in the toolbar)")
print("    Then run all cells from the top.")
print("    Reason: crewai caches the litellm availability check at import time.")
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# *** IMPORTANT: Restart the kernel now before running any other cell. ***
#     Kernel -> Restart Kernel  (or the restart button in the toolbar)
#     Then run all cells from the top.
#     Reason: crewai caches the litellm availability check at import time.

# %%
import os
from dotenv import load_dotenv

load_dotenv()  # loads from .env file if present

# Set your API keys here if not using a .env file
# os.environ["GROQ_API_KEY"] = "your_groq_key_here"
# os.environ["TAVILY_API_KEY"] = "your_tavily_key_here"

GROQ_API_KEY   = os.getenv("GROQ_API_KEY")
TAVILY_API_KEY = os.getenv("TAVILY_API_KEY")

print(f"GROQ_API_KEY:   {'set' if GROQ_API_KEY else 'NOT SET — add to .env'}")
print(f"TAVILY_API_KEY: {'set' if TAVILY_API_KEY else 'NOT SET — add to .env'}")
# Out:
# GROQ_API_KEY:   set
# TAVILY_API_KEY: set

# %% [markdown]
# ---
#
# ## Part 1: Agentic Design Patterns
#
# Before writing code, let's understand the four core design patterns that underpin all agentic frameworks.
#
# ### Pattern 1: Reflection
#
# The agent critiques its own output and iteratively improves it.
#
# ```
# Agent writes code
#     ↓
# Agent reviews its own code → finds bugs
#     ↓
# Agent rewrites improved code
#     ↓
# Agent reviews again → passes → done
# ```
#
# ### Pattern 2: Tool Use
#
# The agent has access to external functions (tools) it can call during reasoning.
#
# ```
# Thought: "I need to find the current stock price of Apple"
# Action: search_web("Apple stock price today")
# Observation: "AAPL: $189.30 as of market close"
# Thought: "Now I can answer the user's question."
# Final Answer: "Apple's stock is $189.30"
# ```
#
# ### Pattern 3: Planning
#
# The agent breaks a complex goal into a sequence of sub-tasks before executing any of them.
#
# ```
# Goal: "Write a research report on climate change"
#
# Plan:
#   1. Search for recent statistics on global temperature rise
#   2. Search for key causes of climate change
#   3. Search for proposed solutions
#   4. Synthesize into a structured report
#   5. Add citations
#
# → Execute each step in order
# ```
#
# ### Pattern 4: Multi-Agent Collaboration
#
# Multiple specialized agents each handle what they're best at, coordinated by an orchestrator.
#
# ```
#                   ┌─────────────────┐
#                   │   ORCHESTRATOR  │
#                   └────────┬────────┘
#               ┌────────────┼────────────┐
#               ▼            ▼            ▼
#         [Researcher]  [Writer]    [Reviewer]
#         finds facts   drafts      critiques
#                            ↓
#                       Final output
# ```
#
# All the frameworks we cover below implement these patterns — just with different APIs and abstractions.

# %% [markdown]
# ---
#
# ## Part 2: AutoGen — Conversational Multi-Agent Framework
#
# ### What is AutoGen?
#
# **AutoGen** (by Microsoft) is a framework where agents communicate through a **conversation protocol**. Each agent is a participant in a chat — they send and receive messages, and can call tools (functions) when needed.
#
# ```
# AutoGen Core Concepts:
#
#   ConversableAgent  ← the base agent class
#        ├─ AssistantAgent  (has an LLM, generates responses)
#        └─ UserProxyAgent  (represents the human, executes tools)
#
#   register_function()  ← attach a Python function as a callable tool
#   initiate_chat()      ← start the conversation between two agents
# ```
#
# ### Our Use Case: Research → Write → Translate Pipeline
#
# We'll build a 3-agent pipeline that:
# 1. **Researcher** searches the web for a given topic
# 2. **Writer** turns the findings into a structured article
# 3. **Translator** translates the article into another language
#
# Each step is a separate `initiate_chat()` call, passing outputs from one agent to the next.

# %%
from autogen import ConversableAgent
from tavily import TavilyClient

# ── LLM Configuration ──────────────────────────────────────────────────────
# Note: AutoGen 0.3.x sends tools using the old OpenAI 'functions' schema,
# which Groq rejects with a 400 error regardless of model.
# Solution: we handle the web search in plain Python (Tavily), inject the
# results into the researcher's message, then let AutoGen handle the
# multi-agent conversation (synthesise → write → translate).
# This is cleaner and teaches the same multi-agent concepts.
groq_config = [
    {
        "model": "llama-3.3-70b-versatile",
        "api_key": GROQ_API_KEY,
        "base_url": "https://api.groq.com/openai/v1",
        "api_type": "openai",
    }
]

llm_config = {"config_list": groq_config, "temperature": 0.3}
print("LLM config ready — using Groq / llama-3.3-70b-versatile")
# Out:
# LLM config ready — using Groq / llama-3.3-70b-versatile
# /opt/homebrew/lib/python3.11/site-packages/flaml/__init__.py:20: UserWarning: flaml.automl is not available. Please install flaml[automl] to enable AutoML functionalities.
#   warnings.warn("flaml.automl is not available. Please install flaml[automl] to enable AutoML functionalities.")

# %%
# ── Tool: Web Search via Tavily ─────────────────────────────────────────────
def search_internet(query: str) -> str:
    """
    Search the web using the Tavily API.

    Args:
        query (str): The search query string.

    Returns:
        str: Search results as a formatted string.
    """
    client = TavilyClient(api_key=TAVILY_API_KEY)
    try:
        response = client.search(query=query, max_results=5)
        # Format results cleanly
        results = []
        for r in response.get("results", []):
            results.append(f"Title: {r.get('title', '')}\nURL: {r.get('url', '')}\nContent: {r.get('content', '')}")
        return "\n\n---\n\n".join(results)
    except Exception as e:
        return f"Search error: {str(e)}"

print("search_internet tool defined.")
# Out:
# search_internet tool defined.

# %%
# ── Plain Python web search (Tavily) ────────────────────────────────────────
# We call Tavily directly in Python instead of through AutoGen's tool system.
# AutoGen 0.3.x uses the deprecated 'functions' API which Groq no longer accepts.
def run_web_search(query: str, max_results: int = 5) -> str:
    """Run a Tavily web search and return formatted results."""
    client = TavilyClient(api_key=TAVILY_API_KEY)
    try:
        response = client.search(query=query, max_results=max_results)
        results = []
        for r in response.get("results", []):
            results.append(
                f"Title: {r.get('title', '')}\n"
                f"URL: {r.get('url', '')}\n"
                f"Content: {r.get('content', '')}"
            )
        return "\n\n---\n\n".join(results)
    except Exception as e:
        return f"Search error: {str(e)}"

print("Web search function ready.")

# ── Agent 1: User Proxy ─────────────────────────────────────────────────────
# The UserProxy acts as the human — no LLM, terminates on 'TERMINATE'.
user_proxy = ConversableAgent(
    name="UserProxy",
    llm_config=False,
    human_input_mode="NEVER",
    code_execution_config=False,
    is_termination_msg=lambda x: "TERMINATE" in (x.get("content") or ""),
    default_auto_reply="Continue if not finished, otherwise say TERMINATE."
)

# ── Agent 2: Researcher ─────────────────────────────────────────────────────
# Receives pre-fetched search results and synthesises them into a report.
researcher_agent = ConversableAgent(
    name="Researcher",
    llm_config=llm_config,
    system_message=(
        "You are a professional research analyst. "
        "You will be given raw web search results on a topic. "
        "Synthesise them into a structured research report with: key facts, "
        "important statistics, key developments, and source URLs. "
        "When your report is complete, end your final message with 'TERMINATE'."
    )
)

# ── Agent 3: Writer ─────────────────────────────────────────────────────────
writer_agent = ConversableAgent(
    name="Writer",
    llm_config=llm_config,
    system_message=(
        "You are a professional content writer. "
        "Take research findings and transform them into a well-structured, "
        "engaging article with: an introduction, 3-4 clearly titled sections, "
        "key takeaways, and proper source citations. "
        "When your article is complete, end with 'TERMINATE'."
    )
)

# ── Agent 4: Translator ─────────────────────────────────────────────────────
translator_agent = ConversableAgent(
    name="Translator",
    llm_config=llm_config,
    system_message=(
        "You are a professional translator. "
        "Translate the given article into Spanish, preserving the original "
        "meaning, tone, structure, and all section headings. "
        "When the translation is complete, end with 'TERMINATE'."
    )
)

print("All agents created.")
# Out:
# Web search function ready.
# All agents created.

# %%
# ── Step 1: Search (Python) then Research (AutoGen) ────────────────────────
RESEARCH_TOPIC = "Recent advances in large language models in 2024 and 2025"

# Step 1a — Run the actual web search in plain Python
print(f"Searching the web for: '{RESEARCH_TOPIC}'...")
raw_search_results = run_web_search(RESEARCH_TOPIC, max_results=5)
print(f"Search complete. Got {len(raw_search_results)} characters of results.")

# Step 1b — Hand results to the Researcher agent to synthesise into a report
# The agent receives the raw results and uses its LLM to analyse + structure them.
print(f"\nResearcher agent synthesising report...")
print("=" * 60)

research_result = user_proxy.initiate_chat(
    researcher_agent,
    message=(
        f"Topic: {RESEARCH_TOPIC}\n\n"
        f"Here are the raw web search results:\n\n{raw_search_results}\n\n"
        "Please synthesise these into a structured research report with key facts, "
        "important statistics, and source URLs."
    ),
    max_turns=4
)

research_findings = research_result.chat_history[-1]["content"].replace("TERMINATE", "").strip()
print("\nResearch complete.")
# Out:
# Searching the web for: 'Recent advances in large language models in 2024 and 2025'...
# Search complete. Got 1507 characters of results.
#
# Researcher agent synthesising report...
# ============================================================
# UserProxy (to Researcher):
#
# Topic: Recent advances in large language models in 2024 and 2025
#
# Here are the raw web search results:
#
# Title: Advances in Large Language Model Training: Insights from ...
# URL: https://www.paperdigest.org/report/?id=advances-in-large-language-model-training-insights-from-iclr-2025-papers
# Content: The recent ICLR 2025 publications have significantly advanced our understanding of large language model (LLM) training, highlighting
#
# ---
#
# Title: Top Large Language Models of 2025 | Best LLMs Compared
# URL: https://www.nurix.ai/blogs/which-llm-most-advanced-today
# Content: In 2025, large language models (LLMs) are powering everything from AI agents to real-time analytics. With rapid advancements in reasoning,
#
# ---
#
# Title: Large Language Models That Will Redefine AI in 2025
# URL: https://www.growexx.com/blog/large-language-models-that-will-redefine-ai-in-2025/
# Content: Explore how large language models will revolutionize AI in 2025, advancing automation, creativity, and transforming business applications.
#
# ---
#
# Title: The Evolving Landscape of Large Language Models (2024 ...
# URL: https://www.linkedin.com/pulse/evolving-landscape-large-language-models-2024-2025-zqgue
# Content: OpenAI's GPT-4o, released in May 2024, marked a significant milestone by enabling real-time understanding and response across text, images, and
#
# ---
#
# Title: The State Of LLMs 2025: Progress, Problems, and Predictions
# URL: https://magazine.sebastianraschka.com/p/state-of-llms-2025
# Content: A 2025 review of large language models, from DeepSeek R1 and RLVR to inference-time scaling, benchmarks, architectures, and predictions for
#
# Please synthesise these into a structured research report with key facts, important statistics, and source URLs.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# [autogen.oai.client: 04-21 23:00:29] {410} WARNING - Model llama-3.3-70b-versatile is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# Researcher (to UserProxy):
#
# **Research Report: Recent Advances in Large Language Models (2024-2025)**
#
# **Key Facts:**
#
# 1. The recent ICLR 2025 publications have significantly advanced our understanding of large language model (LLM) training.
# 2. Large language models are powering various applications, including AI agents and real-time analytics, in 2025.
# 3. OpenAI's GPT-4o, released in May 2024, enabled real-time understanding and response across text, images, and other media.
# 4. The landscape of large language models is evolving rapidly, with advancements in automation, creativity, and business applications.
#
# **Important Statistics:**
#
# * No specific statistics are mentioned in the provided search results. However, the reports and articles suggest a significant increase in the capabilities and applications of large language models in 2024 and 2025.
#
# **Key Developments:**
#
# 1. **Advancements in LLM Training:** ICLR 2025 publications have highlighted significant advancements in large language model training, improving our understanding of LLMs.
# 2. **GPT-4o Release:** OpenAI's GPT-4o, released in May 2024, marked a significant milestone in enabling real-time understanding and response across multiple media types.
# 3. **Increased Adoption:** Large language models are being adopted in various applications, including AI agents, real-time analytics, automation, creativity, and business applications.
# 4. **Emerging Trends:** The reports and articles suggest emerging trends in large language models, including inference-time scaling, benchmarks, architectures, and predictions for future developments.
#
# **Source URLs:**
#
# 1. https://www.paperdigest.org/report/?id=advances-in-large-language-model-training-insights-from-iclr-2025-papers
# 2. https://www.nurix.ai/blogs/which-llm-most-advanced-today
# 3. https://www.growexx.com/blog/large-language-models-that-will-redefine-ai-in-2025/
# 4. https://www.linkedin.com/pulse/evolving-landscape-large-language-models-2024-2025-zqgue
# 5. https://magazine.sebastianraschka.com/p/state-of-llms-2025
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# Research complete.

# %%
# ── Step 2: Write ───────────────────────────────────────────────────────────
print("Starting article writing...")
print("=" * 60)

writing_result = user_proxy.initiate_chat(
    writer_agent,
    message=f"Based on the following research findings, write a well-structured article:\n\n{research_findings}",
    max_turns=4
)

article = writing_result.chat_history[-1]["content"].replace("TERMINATE", "").strip()
print("\nArticle writing complete.")
# Out:
# Starting article writing...
# ============================================================
# UserProxy (to Writer):
#
# Based on the following research findings, write a well-structured article:
#
# **Research Report: Recent Advances in Large Language Models (2024-2025)**
#
# **Key Facts:**
#
# 1. The recent ICLR 2025 publications have significantly advanced our understanding of large language model (LLM) training.
# 2. Large language models are powering various applications, including AI agents and real-time analytics, in 2025.
# 3. OpenAI's GPT-4o, released in May 2024, enabled real-time understanding and response across text, images, and other media.
# 4. The landscape of large language models is evolving rapidly, with advancements in automation, creativity, and business applications.
#
# **Important Statistics:**
#
# * No specific statistics are mentioned in the provided search results. However, the reports and articles suggest a significant increase in the capabilities and applications of large language models in 2024 and 2025.
#
# **Key Developments:**
#
# 1. **Advancements in LLM Training:** ICLR 2025 publications have highlighted significant advancements in large language model training, improving our understanding of LLMs.
# 2. **GPT-4o Release:** OpenAI's GPT-4o, released in May 2024, marked a significant milestone in enabling real-time understanding and response across multiple media types.
# 3. **Increased Adoption:** Large language models are being adopted in various applications, including AI agents, real-time analytics, automation, creativity, and business applications.
# 4. **Emerging Trends:** The reports and articles suggest emerging trends in large language models, including inference-time scaling, benchmarks, architectures, and predictions for future developments.
#
# **Source URLs:**
#
# 1. https://www.paperdigest.org/report/?id=advances-in-large-language-model-training-insights-from-iclr-2025-papers
# 2. https://www.nurix.ai/blogs/which-llm-most-advanced-today
# 3. https://www.growexx.com/blog/large-language-models-that-will-redefine-ai-in-2025/
# 4. https://www.linkedin.com/pulse/evolving-landscape-large-language-models-2024-2025-zqgue
# 5. https://magazine.sebastianraschka.com/p/state-of-llms-2025
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# [autogen.oai.client: 04-21 23:00:36] {410} WARNING - Model llama-3.3-70b-versatile is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# Writer (to UserProxy):
#
# **Introduction to Large Language Models: Recent Advances and Applications**
#
# The field of artificial intelligence has witnessed significant advancements in recent years, particularly in the development of large language models (LLMs). These models have revolutionized the way we interact with machines, enabling real-time understanding and response across various media types. According to recent research findings, the landscape of LLMs is evolving rapidly, with significant advancements in training, applications, and emerging trends (https://www.paperdigest.org/report/?id=advances-in-large-language-model-training-insights-from-iclr-2025-papers). In this article, we will explore the recent advances in LLMs, their applications, and the emerging trends that are shaping the future of AI.
#
# **Advances in Large Language Model Training**
#
# The recent ICLR 2025 publications have significantly advanced our understanding of LLM training, highlighting new techniques and methodologies for improving model performance (https://www.paperdigest.org/report/?id=advances-in-large-language-model-training-insights-from-iclr-2025-papers). These advancements have enabled the development of more sophisticated LLMs, such as OpenAI's GPT-4o, which was released in May 2024. GPT-4o marked a significant milestone in enabling real-time understanding and response across multiple media types, including text, images, and other media (https://www.nurix.ai/blogs/which-llm-most-advanced-today). The improvements in LLM training have also led to increased adoption in various applications, including AI agents, real-time analytics, automation, creativity, and business applications.
#
# **Applications of Large Language Models**
#
# Large language models are powering various applications in 2025, including AI agents and real-time analytics. These models are being used to improve customer service, enhance user experience, and provide personalized recommendations (https://www.growexx.com/blog/large-language-models-that-will-redefine-ai-in-2025/). The increased adoption of LLMs is also driven by their ability to automate tasks, generate creative content, and provide business insights. As the landscape of LLMs continues to evolve, we can expect to see more innovative applications of these models in the future.
#
# **Emerging Trends and Future Developments**
#
# The reports and articles suggest emerging trends in large language models, including inference-time scaling, benchmarks, architectures, and predictions for future developments (https://www.linkedin.com/pulse/evolving-landscape-large-language-models-2024-2025-zqgue). These trends are expected to shape the future of AI, enabling the development of more sophisticated and powerful LLMs. According to industry experts, the future of LLMs will be characterized by increased automation, creativity, and business applications (https://magazine.sebastianraschka.com/p/state-of-llms-2025). As the field continues to evolve, we can expect to see significant advancements in LLMs, leading to new and innovative applications.
#
# **Key Takeaways**
#
# The recent advances in large language models have significant implications for the field of AI. The key takeaways from this research are:
#
# * Large language models are evolving rapidly, with significant advancements in training, applications, and emerging trends.
# * OpenAI's GPT-4o has enabled real-time understanding and response across multiple media types.
# * Large language models are being adopted in various applications, including AI agents, real-time analytics, automation, creativity, and business applications.
# * Emerging trends, such as inference-time scaling, benchmarks, architectures, and predictions for future developments, are expected to shape the future of AI.
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# Article writing complete.

# %%
# ── Step 3: Translate ───────────────────────────────────────────────────────
print("Starting translation to Spanish...")
print("=" * 60)

translation_result = user_proxy.initiate_chat(
    translator_agent,
    message=f"Please translate the following article into Spanish:\n\n{article}",
    max_turns=4
)

translated_article = translation_result.chat_history[-1]["content"].replace("TERMINATE", "").strip()
print("\nTranslation complete.")
# Out:
# Starting translation to Spanish...
# ============================================================
# UserProxy (to Translator):
#
# Please translate the following article into Spanish:
#
# **Introduction to Large Language Models: Recent Advances and Applications**
#
# The field of artificial intelligence has witnessed significant advancements in recent years, particularly in the development of large language models (LLMs). These models have revolutionized the way we interact with machines, enabling real-time understanding and response across various media types. According to recent research findings, the landscape of LLMs is evolving rapidly, with significant advancements in training, applications, and emerging trends (https://www.paperdigest.org/report/?id=advances-in-large-language-model-training-insights-from-iclr-2025-papers). In this article, we will explore the recent advances in LLMs, their applications, and the emerging trends that are shaping the future of AI.
#
# **Advances in Large Language Model Training**
#
# The recent ICLR 2025 publications have significantly advanced our understanding of LLM training, highlighting new techniques and methodologies for improving model performance (https://www.paperdigest.org/report/?id=advances-in-large-language-model-training-insights-from-iclr-2025-papers). These advancements have enabled the development of more sophisticated LLMs, such as OpenAI's GPT-4o, which was released in May 2024. GPT-4o marked a significant milestone in enabling real-time understanding and response across multiple media types, including text, images, and other media (https://www.nurix.ai/blogs/which-llm-most-advanced-today). The improvements in LLM training have also led to increased adoption in various applications, including AI agents, real-time analytics, automation, creativity, and business applications.
#
# **Applications of Large Language Models**
#
# Large language models are powering various applications in 2025, including AI agents and real-time analytics. These models are being used to improve customer service, enhance user experience, and provide personalized recommendations (https://www.growexx.com/blog/large-language-models-that-will-redefine-ai-in-2025/). The increased adoption of LLMs is also driven by their ability to automate tasks, generate creative content, and provide business insights. As the landscape of LLMs continues to evolve, we can expect to see more innovative applications of these models in the future.
#
# **Emerging Trends and Future Developments**
#
# The reports and articles suggest emerging trends in large language models, including inference-time scaling, benchmarks, architectures, and predictions for future developments (https://www.linkedin.com/pulse/evolving-landscape-large-language-models-2024-2025-zqgue). These trends are expected to shape the future of AI, enabling the development of more sophisticated and powerful LLMs. According to industry experts, the future of LLMs will be characterized by increased automation, creativity, and business applications (https://magazine.sebastianraschka.com/p/state-of-llms-2025). As the field continues to evolve, we can expect to see significant advancements in LLMs, leading to new and innovative applications.
#
# **Key Takeaways**
#
# The recent advances in large language models have significant implications for the field of AI. The key takeaways from this research are:
#
# * Large language models are evolving rapidly, with significant advancements in training, applications, and emerging trends.
# * OpenAI's GPT-4o has enabled real-time understanding and response across multiple media types.
# * Large language models are being adopted in various applications, including AI agents, real-time analytics, automation, creativity, and business applications.
# * Emerging trends, such as inference-time scaling, benchmarks, architectures, and predictions for future developments, are expected to shape the future of AI.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# [autogen.oai.client: 04-21 23:00:42] {410} WARNING - Model llama-3.3-70b-versatile is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# Translator (to UserProxy):
#
# **Introducción a los Modelos de Lenguaje Grande: Avances Recientes y Aplicaciones**
#
# El campo de la inteligencia artificial ha presenciado avances significativos en los últimos años, particularmente en el desarrollo de modelos de lenguaje grande (LLMs). Estos modelos han revolucionado la forma en que interactuamos con las máquinas, permitiendo la comprensión y respuesta en tiempo real a través de varios tipos de medios. Según los hallazgos de la investigación reciente, el panorama de los LLMs está evolucionando rápidamente, con avances significativos en la capacitación, las aplicaciones y las tendencias emergentes (https://www.paperdigest.org/report/?id=advances-in-large-language-model-training-insights-from-iclr-2025-papers). En este artículo, exploraremos los avances recientes en los LLMs, sus aplicaciones y las tendencias emergentes que están dando forma al futuro de la IA.
#
# **Avances en la Capacitación de Modelos de Lenguaje Grande**
#
# Las publicaciones recientes de ICLR 2025 han avanzado significativamente nuestra comprensión de la capacitación de LLMs, destacando nuevas técnicas y metodologías para mejorar el rendimiento del modelo (https://www.paperdigest.org/report/?id=advances-in-large-language-model-training-insights-from-iclr-2025-papers). Estos avances han permitido el desarrollo de LLMs más sofisticados, como GPT-4o de OpenAI, que se lanzó en mayo de 2024. GPT-4o marcó un hito significativo al permitir la comprensión y respuesta en tiempo real a través de múltiples tipos de medios, incluyendo texto, imágenes y otros medios (https://www.nurix.ai/blogs/which-llm-most-advanced-today). Las mejoras en la capacitación de LLMs también han llevado a una mayor adopción en diversas aplicaciones, incluyendo agentes de IA, análisis en tiempo real, automatización, creatividad y aplicaciones comerciales.
#
# **Aplicaciones de Modelos de Lenguaje Grande**
#
# Los modelos de lenguaje grande están impulsando diversas aplicaciones en 2025, incluyendo agentes de IA y análisis en tiempo real. Estos modelos se están utilizando para mejorar el servicio al cliente, mejorar la experiencia del usuario y proporcionar recomendaciones personalizadas (https://www.growexx.com/blog/large-language-models-that-will-redefine-ai-in-2025/). La adopción creciente de LLMs también está impulsada por su capacidad para automatizar tareas, generar contenido creativo y proporcionar información comercial. A medida que el panorama de los LLMs continúa evolucionando, podemos esperar ver más aplicaciones innovadoras de estos modelos en el futuro.
#
# **Tendencias Emergentes y Desarrollos Futuros**
#
# Los informes y artículos sugieren tendencias emergentes en los modelos de lenguaje grande, incluyendo la escalabilidad en tiempo de inferencia, benchmarks, arquitecturas y predicciones para desarrollos futuros (https://www.linkedin.com/pulse/evolving-landscape-large-language-models-2024-2025-zqgue). Estas tendencias se espera que den forma al futuro de la IA, permitiendo el desarrollo de LLMs más sofisticados y poderosos. Según los expertos de la industria, el futuro de los LLMs estará caracterizado por una mayor automatización, creatividad y aplicaciones comerciales (https://magazine.sebastianraschka.com/p/state-of-llms-2025). A medida que el campo continúa evolucionando, podemos esperar ver avances significativos en los LLMs, lo que llevará a nuevas y innovadoras aplicaciones.
#
# **Conclusión**
#
# Los avances recientes en los modelos de lenguaje grande tienen implicaciones significativas para el campo de la IA. Las conclusiones clave de esta investigación son:
#
# * Los modelos de lenguaje grande están evolucionando rápidamente, con avances significativos en la capacitación, las aplicaciones y las tendencias emergentes.
# * GPT-4o de OpenAI ha permitido la comprensión y respuesta en tiempo real a través de múltiples tipos de medios.
# * Los modelos de lenguaje grande están siendo adoptados en diversas aplicaciones, incluyendo agentes de IA, análisis en tiempo real, automatización, creatividad y aplicaciones comerciales.
# * Las tendencias emergentes, como la escalabilidad en tiempo de inferencia, benchmarks, arquitecturas y predicciones para desarrollos futuros, se espera que den forma al futuro de la IA.
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# Translation complete.

# %%
# ── Final Output ────────────────────────────────────────────────────────────
print("\n" + "=" * 60)
print("PIPELINE COMPLETE — Final Outputs")
print("=" * 60)

print("\n--- RESEARCH FINDINGS (excerpt) ---")
print(research_findings[:800] + "..." if len(research_findings) > 800 else research_findings)

print("\n--- ARTICLE (excerpt) ---")
print(article[:800] + "..." if len(article) > 800 else article)

print("\n--- TRANSLATED ARTICLE (excerpt) ---")
print(translated_article[:800] + "..." if len(translated_article) > 800 else translated_article)
# Out:
# ============================================================
# PIPELINE COMPLETE — Final Outputs
# ============================================================
#
# --- RESEARCH FINDINGS (excerpt) ---
# **Research Report: Recent Advances in Large Language Models (2024-2025)**
#
# **Key Facts:**
#
# 1. The recent ICLR 2025 publications have significantly advanced our understanding of large language model (LLM) training.
# 2. Large language models are powering various applications, including AI agents and real-time analytics, in 2025.
# 3. OpenAI's GPT-4o, released in May 2024, enabled real-time understanding and response across text, images, and other media.
# 4. The landscape of large language models is evolving rapidly, with advancements in automation, creativity, and business applications.
#
# **Important Statistics:**
#
# * No specific statistics are mentioned in the provided search results. However, the reports and articles suggest a significant increase in the capabilities and applications of large la...
#
# --- ARTICLE (excerpt) ---
# **Introduction to Large Language Models: Recent Advances and Applications**
#
# The field of artificial intelligence has witnessed significant advancements in recent years, particularly in the development of large language models (LLMs). These models have revolutionized the way we interact with machines, enabling real-time understanding and response across various media types. According to recent research findings, the landscape of LLMs is evolving rapidly, with significant advancements in training, applications, and emerging trends (https://www.paperdigest.org/report/?id=advances-in-large-language-model-training-insights-from-iclr-2025-papers). In this article, we will explore the recent advances in LLMs, their applications, and the emerging trends that are shaping the future of AI.
#
# **Advan...
#
# --- TRANSLATED ARTICLE (excerpt) ---
# **Introducción a los Modelos de Lenguaje Grande: Avances Recientes y Aplicaciones**
#
# El campo de la inteligencia artificial ha presenciado avances significativos en los últimos años, particularmente en el desarrollo de modelos de lenguaje grande (LLMs). Estos modelos han revolucionado la forma en que interactuamos con las máquinas, permitiendo la comprensión y respuesta en tiempo real a través de varios tipos de medios. Según los hallazgos de la investigación reciente, el panorama de los LLMs está evolucionando rápidamente, con avances significativos en la capacitación, las aplicaciones y las tendencias emergentes (https://www.paperdigest.org/report/?id=advances-in-large-language-model-training-insights-from-iclr-2025-papers). En este artículo, exploraremos los avances recientes en los LLM...

# %% [markdown]
# ### What just happened?
#
# ```
# AutoGen Pipeline — What happened under the hood:
#
#   [Python]  Tavily.search("LLM advances 2024") ──► Raw search results
#                                                            │
#                                            injected into first message
#                                                            │
#   UserProxy ──► Researcher: "Here are raw results, synthesise a report"
#   Researcher ──► [LLM analyses and structures the data]
#   Researcher ──► "Here are the findings... TERMINATE"
#
#   UserProxy ──► Writer: "Write an article from these findings"
#   Writer ──► "Here is the article... TERMINATE"
#
#   UserProxy ──► Translator: "Translate to Spanish"
#   Translator ──► "Aquí está el artículo... TERMINATE"
# ```
#
# > **Note on tool calling:** AutoGen 0.3.x uses the deprecated OpenAI `functions` schema
# > for tool registration, which Groq no longer accepts. Rather than fight framework
# > internals, we call Tavily directly in Python and inject the results — this is actually
# > the pattern used in many production pipelines where tool execution is handled outside
# > the LLM loop for reliability and auditability.
#
# Each agent had a **single responsibility**, communicated via messages, and knew when to stop (`TERMINATE`). The `UserProxy` served as the glue — passing outputs from one agent as the input to the next.
#
# ---
#
# ## Part 3: CrewAI — Role-Based Agent Orchestration
#
# ### What is CrewAI?
#
# **CrewAI** models agent collaboration as a **crew** — like a team of people at work. Each crew member has:
# - A **role** (job title)
# - A **goal** (what they're trying to achieve)
# - A **backstory** (personality/expertise context for the LLM)
# - **Tools** (what they can use)
# - **Tasks** (the specific work assigned to them)
#
# ```
# CrewAI Concepts:
#
#   Agent(role, goal, backstory, tools, llm)
#       ↑ the "who"
#
#   Task(description, agent, expected_output, context)
#       ↑ the "what"
#
#   Crew(agents, tasks, process)
#       ↑ the "how" — sequential or hierarchical
#
#   crew.kickoff() → runs the whole pipeline
# ```
#
# ### AutoGen vs CrewAI
#
# | | AutoGen | CrewAI |
# |---|---|---|
# | Mental model | Agents in a conversation | Crew members on a project |
# | Coordination | Chat messages | Tasks with explicit dependencies |
# | Control flow | `initiate_chat()` | `crew.kickoff()` |
# | Best for | Back-and-forth reasoning | Structured pipelines with clear roles |
# | Tool definition | `register_function()` | `@tool` decorator |

# %%
import os
from crewai import Agent, Task, Crew, LLM
from crewai.tools import tool
from tavily import TavilyClient
import time

# litellm reads GROQ_API_KEY from environment — set it explicitly here
# so it works even if the .env file was not loaded before crewai imported.
os.environ["GROQ_API_KEY"] = GROQ_API_KEY

# llama-3.1-8b-instant: 560 t/s, ~1M TPM on free tier (vs 12K for 70b).
# max_tokens=800 caps per-response size to stay well under rate limits.
crew_llm = LLM(
    model="groq/llama-3.1-8b-instant",
    temperature=0.3,
    max_tokens=800,
    api_key=GROQ_API_KEY
)

print("CrewAI LLM configured — groq/llama-3.1-8b-instant")
# Out:
# CrewAI LLM configured — groq/llama-3.1-8b-instant

# %%
# ── Tool: Web Search (CrewAI style with @tool decorator) ────────────────────
@tool("Web Search Tool")
def crew_search_internet(query: str) -> str:
    """
    Search the web for the given query using the Tavily API.
    Always pass a clear, specific search query string as input.

    Args:
        query (str): The search query.

    Returns:
        str: Web search results including titles, URLs, and content snippets.
    """
    client = TavilyClient(api_key=TAVILY_API_KEY)
    try:
        response = client.search(query=query, max_results=5)
        results = []
        for r in response.get("results", []):
            results.append(f"Title: {r.get('title', '')}\nURL: {r.get('url', '')}\nContent: {r.get('content', '')}")
        return "\n\n---\n\n".join(results)
    except Exception as e:
        return f"Search error: {str(e)}"

print("CrewAI search tool defined.")
# Out:
# CrewAI search tool defined.

# %%
# Agents with short backstories to minimise prompt token usage.
researcher = Agent(
    role="Research Analyst",
    goal="Find key facts using web search and return exactly 5 bullet points with source URLs.",
    backstory="Expert researcher who produces brief bullet-point summaries.",
    tools=[crew_search_internet],
    verbose=False,
    llm=crew_llm
)
writer = Agent(
    role="Content Writer",
    goal="Turn bullet points into a 150-word article with 4 paragraphs.",
    backstory="Concise tech writer who produces short, structured articles.",
    verbose=False,
    llm=crew_llm
)
translator = Agent(
    role="Translator",
    goal="Translate the given English text into Spanish accurately.",
    backstory="Professional English-Spanish translator.",
    verbose=False,
    llm=crew_llm
)
print("Agents defined.")
# Out:
# Agents defined.

# %%
TOPIC = "Recent advances in large language models in 2024 and 2025"

research_task = Task(
    description=(
        f"Search for: {TOPIC}. "
        "Return ONLY 5 bullet points. Each bullet: one key fact + source URL. "
        "Each bullet must be under 25 words. No intro, no conclusion."
    ),
    agent=researcher,
    expected_output="5 bullet points, each under 25 words, with source URL."
)
writing_task = Task(
    description=(
        "Using the 5 research bullets, write a SHORT article: "
        "intro (1 sentence), 2 body paragraphs (2 sentences each), conclusion (1 sentence). "
        "Total: 80-100 words maximum."
    ),
    agent=writer,
    context=[research_task],
    expected_output="An 80-100 word article, 4 paragraphs."
)
translation_task = Task(
    description="Translate the article into Spanish. Output the translation only.",
    agent=translator,
    context=[writing_task],
    expected_output="The article translated into Spanish."
)
print("Tasks defined.")
# Out:
# Tasks defined.

# %%
pip install crewai-tools
# Out:
# Requirement already satisfied: crewai-tools in /opt/homebrew/lib/python3.11/site-packages (1.14.2)
# Requirement already satisfied: beautifulsoup4~=4.13.4 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools) (4.13.5)
# Requirement already satisfied: crewai==1.14.2 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools) (1.14.2)
# Requirement already satisfied: pymupdf~=1.26.6 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools) (1.26.7)
# Requirement already satisfied: python-docx~=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools) (1.2.0)
# Requirement already satisfied: pytube~=15.0.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools) (15.0.0)
# Requirement already satisfied: requests<3,>=2.33.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools) (2.33.1)
# Requirement already satisfied: tiktoken~=0.8.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools) (0.8.0)
# Requirement already satisfied: youtube-transcript-api~=1.2.2 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools) (1.2.4)
# Requirement already satisfied: aiofiles~=24.1.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (24.1.0)
# Requirement already satisfied: aiosqlite~=0.21.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (0.21.0)
# Requirement already satisfied: appdirs~=1.4.4 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (1.4.4)
# Requirement already satisfied: chromadb~=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (1.1.1)
# Requirement already satisfied: click~=8.1.7 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (8.1.8)
# Requirement already satisfied: httpx~=0.28.1 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (0.28.1)
# Requirement already satisfied: instructor>=1.3.3 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (1.15.1)
# Requirement already satisfied: json-repair~=0.25.2 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (0.25.3)
# Requirement already satisfied: json5~=0.10.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (0.10.0)
# Requirement already satisfied: jsonref~=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (1.1.0)
# Requirement already satisfied: lancedb<0.30.1,>=0.29.2 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (0.30.0)
# Requirement already satisfied: mcp~=1.26.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (1.26.0)
# Requirement already satisfied: openai<3,>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (2.32.0)
# Requirement already satisfied: openpyxl~=3.1.5 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (3.1.5)
# Requirement already satisfied: opentelemetry-api~=1.34.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http~=1.34.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk~=1.34.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (1.34.1)
# Requirement already satisfied: pdfplumber~=0.11.4 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (0.11.9)
# Requirement already satisfied: portalocker~=2.7.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (2.7.0)
# Requirement already satisfied: pydantic-settings~=2.10.1 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (2.10.1)
# Requirement already satisfied: pydantic~=2.11.9 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (2.11.10)
# Requirement already satisfied: pyjwt<3,>=2.9.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (2.12.1)
# Requirement already satisfied: python-dotenv~=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (1.1.1)
# Requirement already satisfied: pyyaml~=6.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (6.0.3)
# Requirement already satisfied: regex~=2026.1.15 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (2026.1.15)
# Requirement already satisfied: textual>=7.5.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (8.2.4)
# Requirement already satisfied: tokenizers<1,>=0.21 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (0.22.2)
# Requirement already satisfied: tomli-w~=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (1.1.0)
# Requirement already satisfied: tomli~=2.0.2 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (2.0.2)
# Requirement already satisfied: uv~=0.11.6 in /opt/homebrew/lib/python3.11/site-packages (from crewai==1.14.2->crewai-tools) (0.11.7)
# Requirement already satisfied: typing_extensions>=4.0 in /Users/delishariyonadsouza/Library/Python/3.11/lib/python/site-packages (from aiosqlite~=0.21.0->crewai==1.14.2->crewai-tools) (4.15.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/lib/python3.11/site-packages (from beautifulsoup4~=4.13.4->crewai-tools) (2.8.3)
# Requirement already satisfied: build>=1.0.3 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (1.4.3)
# Requirement already satisfied: pybase64>=1.4.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (0.45.0)
# Requirement already satisfied: numpy>=1.22.5 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (1.26.4)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (1.24.4)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (1.34.1)
# Requirement already satisfied: pypika>=0.48.9 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (7.7.0)
# Requirement already satisfied: importlib-resources in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (0.23.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (9.1.4)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (3.11.8)
# Requirement already satisfied: rich>=10.11.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (14.3.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (4.26.0)
# Requirement already satisfied: anyio in /opt/homebrew/lib/python3.11/site-packages (from httpx~=0.28.1->crewai==1.14.2->crewai-tools) (4.13.0)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.11/site-packages (from httpx~=0.28.1->crewai==1.14.2->crewai-tools) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.11/site-packages (from httpx~=0.28.1->crewai==1.14.2->crewai-tools) (1.0.9)
# Requirement already satisfied: idna in /opt/homebrew/lib/python3.11/site-packages (from httpx~=0.28.1->crewai==1.14.2->crewai-tools) (3.12)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/lib/python3.11/site-packages (from httpcore==1.*->httpx~=0.28.1->crewai==1.14.2->crewai-tools) (0.16.0)
# Requirement already satisfied: deprecation>=2.1.0 in /opt/homebrew/lib/python3.11/site-packages (from lancedb<0.30.1,>=0.29.2->crewai==1.14.2->crewai-tools) (2.1.0)
# Requirement already satisfied: packaging>=23.0 in /Users/delishariyonadsouza/Library/Python/3.11/lib/python/site-packages (from lancedb<0.30.1,>=0.29.2->crewai==1.14.2->crewai-tools) (26.1)
# Requirement already satisfied: pyarrow>=16 in /opt/homebrew/lib/python3.11/site-packages (from lancedb<0.30.1,>=0.29.2->crewai==1.14.2->crewai-tools) (24.0.0)
# Requirement already satisfied: lance-namespace>=0.3.2 in /opt/homebrew/lib/python3.11/site-packages (from lancedb<0.30.1,>=0.29.2->crewai==1.14.2->crewai-tools) (0.6.1)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/homebrew/lib/python3.11/site-packages (from mcp~=1.26.0->crewai==1.14.2->crewai-tools) (0.4.3)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/homebrew/lib/python3.11/site-packages (from mcp~=1.26.0->crewai==1.14.2->crewai-tools) (0.0.26)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/homebrew/lib/python3.11/site-packages (from mcp~=1.26.0->crewai==1.14.2->crewai-tools) (3.3.4)
# Requirement already satisfied: starlette>=0.27 in /opt/homebrew/lib/python3.11/site-packages (from mcp~=1.26.0->crewai==1.14.2->crewai-tools) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /opt/homebrew/lib/python3.11/site-packages (from mcp~=1.26.0->crewai==1.14.2->crewai-tools) (0.4.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/lib/python3.11/site-packages (from openai<3,>=2.0.0->crewai==1.14.2->crewai-tools) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/homebrew/lib/python3.11/site-packages (from openai<3,>=2.0.0->crewai==1.14.2->crewai-tools) (0.13.0)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.11/site-packages (from openai<3,>=2.0.0->crewai==1.14.2->crewai-tools) (1.3.1)
# Requirement already satisfied: et-xmlfile in /opt/homebrew/lib/python3.11/site-packages (from openpyxl~=3.1.5->crewai==1.14.2->crewai-tools) (2.0.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-api~=1.34.0->crewai==1.14.2->crewai-tools) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /opt/homebrew/lib/python3.11/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.34.0->crewai==1.14.2->crewai-tools) (3.23.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai==1.14.2->crewai-tools) (1.74.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai==1.14.2->crewai-tools) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai==1.14.2->crewai-tools) (1.34.1)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-proto==1.34.1->opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai==1.14.2->crewai-tools) (5.29.6)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-sdk~=1.34.0->crewai==1.14.2->crewai-tools) (0.55b1)
# Requirement already satisfied: pdfminer.six==20251230 in /opt/homebrew/lib/python3.11/site-packages (from pdfplumber~=0.11.4->crewai==1.14.2->crewai-tools) (20251230)
# Requirement already satisfied: Pillow>=9.1 in /opt/homebrew/lib/python3.11/site-packages (from pdfplumber~=0.11.4->crewai==1.14.2->crewai-tools) (12.2.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /opt/homebrew/lib/python3.11/site-packages (from pdfplumber~=0.11.4->crewai==1.14.2->crewai-tools) (5.7.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from pdfminer.six==20251230->pdfplumber~=0.11.4->crewai==1.14.2->crewai-tools) (3.4.7)
# Requirement already satisfied: cryptography>=36.0.0 in /opt/homebrew/lib/python3.11/site-packages (from pdfminer.six==20251230->pdfplumber~=0.11.4->crewai==1.14.2->crewai-tools) (46.0.7)
# Requirement already satisfied: six>=1.5 in /Users/delishariyonadsouza/Library/Python/3.11/lib/python/site-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /Users/delishariyonadsouza/Library/Python/3.11/lib/python/site-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /opt/homebrew/lib/python3.11/site-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic~=2.11.9->crewai==1.14.2->crewai-tools) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/homebrew/lib/python3.11/site-packages (from pydantic~=2.11.9->crewai==1.14.2->crewai-tools) (2.33.2)
# Requirement already satisfied: lxml>=3.1.0 in /opt/homebrew/lib/python3.11/site-packages (from python-docx~=1.2.0->crewai-tools) (6.1.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2.33.0->crewai-tools) (2.6.3)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /opt/homebrew/lib/python3.11/site-packages (from tokenizers<1,>=0.21->crewai==1.14.2->crewai-tools) (1.11.0)
# Requirement already satisfied: filelock>=3.10.0 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai==1.14.2->crewai-tools) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai==1.14.2->crewai-tools) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai==1.14.2->crewai-tools) (1.4.3)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /opt/homebrew/lib/python3.11/site-packages (from youtube-transcript-api~=1.2.2->crewai-tools) (0.7.1)
# Requirement already satisfied: pyproject_hooks in /opt/homebrew/lib/python3.11/site-packages (from build>=1.0.3->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (1.2.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber~=0.11.4->crewai==1.14.2->crewai-tools) (2.0.0)
# Requirement already satisfied: pycparser in /opt/homebrew/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber~=0.11.4->crewai==1.14.2->crewai-tools) (3.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /opt/homebrew/lib/python3.11/site-packages (from instructor>=1.3.3->crewai==1.14.2->crewai-tools) (3.13.5)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /opt/homebrew/lib/python3.11/site-packages (from instructor>=1.3.3->crewai==1.14.2->crewai-tools) (0.18.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /opt/homebrew/lib/python3.11/site-packages (from instructor>=1.3.3->crewai==1.14.2->crewai-tools) (3.1.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai==1.14.2->crewai-tools) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai==1.14.2->crewai-tools) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai==1.14.2->crewai-tools) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai==1.14.2->crewai-tools) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai==1.14.2->crewai-tools) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai==1.14.2->crewai-tools) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai==1.14.2->crewai-tools) (1.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai==1.14.2->crewai-tools) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/homebrew/lib/python3.11/site-packages (from rich>=10.11.0->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/delishariyonadsouza/Library/Python/3.11/lib/python/site-packages (from rich>=10.11.0->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (2.20.0)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/homebrew/lib/python3.11/site-packages (from typer>=0.9.0->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/homebrew/lib/python3.11/site-packages (from typer>=0.9.0->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (0.0.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (0.30.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (0.10)
# Requirement already satisfied: lance-namespace-urllib3-client==0.6.1 in /opt/homebrew/lib/python3.11/site-packages (from lance-namespace>=0.3.2->lancedb<0.30.1,>=0.29.2->crewai==1.14.2->crewai-tools) (0.6.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (0.1.2)
# Requirement already satisfied: flatbuffers in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (25.12.19)
# Requirement already satisfied: sympy in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (1.14.0)
# Requirement already satisfied: mdit-py-plugins in /opt/homebrew/lib/python3.11/site-packages (from textual>=7.5.0->crewai==1.14.2->crewai-tools) (0.5.0)
# Requirement already satisfied: platformdirs<5,>=3.6.0 in /Users/delishariyonadsouza/Library/Python/3.11/lib/python/site-packages (from textual>=7.5.0->crewai==1.14.2->crewai-tools) (4.9.6)
# Requirement already satisfied: linkify-it-py<3,>=1 in /opt/homebrew/lib/python3.11/site-packages (from markdown-it-py[linkify]>=2.1.0->textual>=7.5.0->crewai==1.14.2->crewai-tools) (2.1.0)
# Requirement already satisfied: uc-micro-py in /opt/homebrew/lib/python3.11/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.1.0->textual>=7.5.0->crewai==1.14.2->crewai-tools) (2.0.0)
# Requirement already satisfied: httptools>=0.6.3 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/homebrew/lib/python3.11/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb~=1.1.0->crewai==1.14.2->crewai-tools) (1.3.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import time

from crewai_tools import BraveSearchTool

def run_with_retry(crew_obj, max_attempts=5):
    for attempt in range(1, max_attempts + 1):
        try:
            return crew_obj.kickoff()
        except Exception as e:
            err = str(e)
            if "rate_limit" in err.lower() or "429" in err or "RateLimitError" in err:
                wait = attempt * 30
                print(f"  Rate limit hit (attempt {attempt}/{max_attempts}). Sleeping {wait}s...")
                time.sleep(wait)
            else:
                raise
    print("All retries exhausted. Wait a minute then re-run this cell.")
    return None

crew = Crew(
    agents=[researcher, writer, translator],
    tasks=[research_task, writing_task, translation_task],
    verbose=False
)
print("Starting crew...")
crew_result = run_with_retry(crew)
if crew_result:
    print("Done.")
# Out:
# Starting crew...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Done.

# %%
if crew_result is None:
    print("No result — rate limit retries exhausted. Re-run the kickoff cell.")
else:
    print("\n" + "=" * 60)
    print("CREWAI RESULTS")
    print("=" * 60)

    print("\n--- RESEARCH REPORT ---")
    print(str(crew_result.tasks_output[0])[:800])

    print("\n--- ARTICLE ---")
    print(str(crew_result.tasks_output[1])[:800])

    print("\n--- SPANISH TRANSLATION ---")
    print(str(crew_result.tasks_output[2])[:800])
# Out:
# ============================================================
# CREWAI RESULTS
# ============================================================
#
# --- RESEARCH REPORT ---
# • Large language models will redefine AI in 2025, advancing automation, creativity, and transforming business applications. - https://www.growexx.com/blog/large-language-models-that-will-redefine-ai-in-2025/
# • Top large language models of 2025 include LLaMA, PaLM, and BLOOM, each with unique strengths and applications. - https://www.nurix.ai/blogs/which-llm-most-advanced-today
# • ICLR 2025 publications have significantly advanced our understanding of large language model training and its applications. - https://www.paperdigest.org/report/?id=advances-in-large-language-model-training-insights-from-iclr-2025-papers
# • LLMs will be used to identify patterns in complex biological data captured by established brain imaging techniques in 2025. - https://www.psychologytoday.com/us/blog/the-future-b
#
# --- ARTICLE ---
# Large language models are poised to revolutionize the field of artificial intelligence in 2025.
#
# Advancements in large language models will transform business applications, enabling automation and creativity at unprecedented scales. These models will also unlock new possibilities in fields such as healthcare and finance, where complex data analysis is crucial.
#
# The top large language models of 2025, including LLaMA, PaLM, and BLOOM, have unique strengths and applications that will be leveraged in various industries. These models have been significantly advanced through research and development.
#
# As the field of large language models continues to evolve, we can expect to see significant breakthroughs in the coming year, including the use of LLMs to identify patterns in complex biological da
#
# --- SPANISH TRANSLATION ---
# La revolución de los modelos de lenguaje grande está a punto de transformar el campo de la inteligencia artificial en 2025.
#
# Los avances en los modelos de lenguaje grande transformarán las aplicaciones empresariales, permitiendo la automatización y la creatividad a escalas sin precedentes. Estos modelos también desbloquearán nuevas posibilidades en campos como la salud y la finanza, donde el análisis de datos complejos es crucial.
#
# Los mejores modelos de lenguaje grande de 2025, incluyendo LLaMA, PaLM y BLOOM, tienen fortalezas y aplicaciones únicas que se aprovecharán en diversas industrias. Estos modelos han sido significativamente avanzados a través de la investigación y el desarrollo.
#
# A medida que continúa evolucionando el campo de los modelos de lenguaje grande, podemos esperar ver a

# %% [markdown]
# ### What just happened?
#
# ```
# CrewAI Pipeline — Under the hood:
#
#   crew.kickoff()
#        │
#        ├─► Task 1 → researcher runs → uses search tool → produces report
#        │         └─ output fed as context into Task 2
#        │
#        ├─► Task 2 → writer runs → reads research context → writes article
#        │         └─ output fed as context into Task 3
#        │
#        └─► Task 3 → translator runs → reads article context → translates
#
#   CrewAI manages the dependency chain automatically via context=[...]
# ```
#
# Notice how CrewAI's `context=[task]` is more explicit than AutoGen's sequential `initiate_chat()` calls — the dependencies are declared upfront rather than managed manually.
#
# ---
#
# ## Part 4: Devyan — A 4-Agent Software Development Pipeline
#
# ### What is Devyan?
#
# **Devyan** is a multi-agent software development assistant. Instead of a single agent writing code (which leads to bugs, poor architecture, and no testing), Devyan uses **four specialized agents** that mirror a real software team:
#
# ```
# DEVYAN PIPELINE
# ──────────────────────────────────────────────────────
#
#   User: "Build a Python function to sort a list of dicts by key"
#           │
#           ▼
#   ┌─────────────────┐
#   │  ARCHITECT      │  Designs the solution architecture
#   │  Agent          │  "We need: input validation, sort function,
#   └────────┬────────┘   edge case handling..."
#            │ architecture doc
#            ▼
#   ┌─────────────────┐
#   │  PROGRAMMER     │  Implements the code per architecture
#   │  Agent          │  Writes working Python code
#   └────────┬────────┘
#            │ code
#            ▼
#   ┌─────────────────┐
#   │  TESTER         │  Writes and runs test cases
#   │  Agent          │  Unit tests, edge cases, assertions
#   └────────┬────────┘
#            │ test results
#            ▼
#   ┌─────────────────┐
#   │  REVIEWER       │  Reviews everything and produces final docs
#   │  Agent          │  Code quality, test coverage, usage instructions
#   └─────────────────┘
#            │
#            ▼
#   Final: Code + Tests + Documentation
# ──────────────────────────────────────────────────────
# ```

# %%
import os
from crewai import Agent, Task, Crew, LLM
from textwrap import dedent
import time

os.environ["GROQ_API_KEY"] = GROQ_API_KEY

# llama-3.1-8b-instant: faster and higher rate limits than 70b.
# max_tokens=800 caps code output size to avoid TPM exhaustion.
devyan_llm = LLM(
    model="groq/llama-3.1-8b-instant",
    temperature=0.2,
    max_tokens=800,
    api_key=GROQ_API_KEY
)

print("Devyan LLM configured — groq/llama-3.1-8b-instant")
# Out:
# Devyan LLM configured — groq/llama-3.1-8b-instant

# %%
# Short backstories to minimise token usage.
architect = Agent(
    role="Software Architect",
    goal="Output a function signature, parameter descriptions, return type, and 3 edge cases. Max 100 words.",
    backstory="Architect who writes concise design notes.",
    allow_delegation=False, verbose=False, llm=devyan_llm
)
programmer = Agent(
    role="Python Developer",
    goal="Implement the function as a single clean Python code block with type hints and docstring.",
    backstory="Python developer who writes concise, working code.",
    allow_delegation=False, verbose=False, llm=devyan_llm
)
tester = Agent(
    role="QA Engineer",
    goal="Write exactly 5 pytest test functions as a single code block. No explanations.",
    backstory="QA engineer who writes concise targeted tests.",
    allow_delegation=False, verbose=False, llm=devyan_llm
)
reviewer = Agent(
    role="Code Reviewer",
    goal="Output 3 feedback bullets and one short usage paragraph. Max 80 words total.",
    backstory="Tech lead who writes brief, actionable reviews.",
    allow_delegation=False, verbose=False, llm=devyan_llm
)
print("Devyan agents defined.")
# Out:
# Devyan agents defined.

# %%
from crewai import Task
USER_PROBLEM = (
    "Build process_students(records: list[dict], min_score: float) -> dict that "
    "filters by min_score, sorts descending, returns {filtered, average, top_student}."
)

architecture_task = Task(
    description=(
        f"Design: {USER_PROBLEM} "
        "Output: function signature with type hints, param descriptions, return type, "
        "3 edge cases. Maximum 100 words."
    ),
    agent=architect,
    expected_output="Function signature, params, return, 3 edge cases. Under 100 words."
)
implementation_task = Task(
    description=(
        "Implement process_students() per the architecture. "
        "Output ONLY a Python code block. Type hints, docstring, edge cases. No prose."
    ),
    agent=programmer,
    context=[architecture_task],
    expected_output="A Python code block only."
)
testing_task = Task(
    description=(
        "Write exactly 5 pytest test functions for process_students(). "
        "Output ONLY the test code block. No prose, no explanations."
    ),
    agent=tester,
    context=[implementation_task],
    expected_output="Exactly 5 pytest functions as a code block."
)
reviewing_task = Task(
    description=(
        "Review the code and tests. Output ONLY: "
        "3 bullet points of feedback, then 1 sentence on how to run it. "
        "Max 80 words total."
    ),
    agent=reviewer,
    context=[architecture_task, implementation_task, testing_task],
    expected_output="3 bullets + 1 sentence. Under 80 words."
)
print("Devyan tasks defined.")
# Out:
# Devyan tasks defined.

# %%
devyan_crew = Crew(
    agents=[architect, programmer, tester, reviewer],
    tasks=[architecture_task, implementation_task, testing_task, reviewing_task],
    verbose=False
)
print("Devyan starting...")
print("Problem:", USER_PROBLEM)
print("=" * 60)
devyan_result = run_with_retry(devyan_crew)
if devyan_result:
    print("Devyan run complete.")
# Out:
# Devyan starting...
# Problem: Build process_students(records: list[dict], min_score: float) -> dict that filters by min_score, sorts descending, returns {filtered, average, top_student}.
# ============================================================
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# Devyan run complete.
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
if devyan_result is None:
    print("No result — rate limit retries exhausted. Re-run the kickoff cell.")
else:
    labels = ["ARCHITECTURE", "IMPLEMENTATION", "TEST SUITE", "REVIEW & DOCS"]

    print("\n" + "=" * 60)
    print("DEVYAN — FINAL DELIVERABLES")
    print("=" * 60)

    try:
        outputs = devyan_result.tasks_output
    except:
        outputs = [t.output for t in devyan_result.tasks]

    for i, (label, output) in enumerate(zip(labels, outputs)):
        print("\n" + "-" * 60)
        print(f"[{i+1}] {label}")
        print("-" * 60)
        print(str(output))
# Out:
# ============================================================
# DEVYAN — FINAL DELIVERABLES
# ============================================================
#
# ------------------------------------------------------------
# [1] ARCHITECTURE
# ------------------------------------------------------------
# **Function Signature**
# ```python
# def process_students(records: list[dict], min_score: float) -> dict:
# ```
#
# **Parameter Descriptions**
#
# - `records`: A list of dictionaries containing student records.
# - `min_score`: The minimum score to filter student records.
#
# **Return Type**
# ```python
# dict: {
#     'filtered': list[dict],  # List of filtered student records
#     'average': float,  # Average score of filtered student records
#     'top_student': dict  # Top student record with the highest score
# }
# ```
#
# **Edge Cases**
#
# 1. **Empty records**: `process_students([], 0.0)` returns `{'filtered': [], 'average': 0.0, 'top_student': None}`.
# 2. **No students with min_score**: `process_students([{'name': 'John', 'score': 0.0}], 1.0)` returns `{'filtered': [], 'average': 0.0, 'top_student': None}`.
# 3. **Single student with min_score**: `process_students([{'name': 'John', 'score': 1.0}], 1.0)` returns `{'filtered': [{'name': 'John', 'score': 1.0}], 'average': 1.0, 'top_student': {'name': 'John', 'score': 1.0}}`.
#
# ------------------------------------------------------------
# [2] IMPLEMENTATION
# ------------------------------------------------------------
# ```python
# def process_students(records: list[dict], min_score: float) -> dict:
#     """
#     Process student records based on a minimum score.
#
#     Args:
#     records (list[dict]): A list of dictionaries containing student records.
#     min_score (float): The minimum score to filter student records.
#
#     Returns:
#     dict: A dictionary containing filtered student records, average score, and top student record.
#     """
#     filtered_records = [record for record in records if 'score' in record and record['score'] >= min_score]
#     if not filtered_records:
#         return {'filtered': [], 'average': 0.0, 'top_student': None}
#
#     average_score = sum(record['score'] for record in filtered_records) / len(filtered_records)
#     top_student = max(filtered_records, key=lambda x: x['score'])
#
#     return {
#         'filtered': filtered_records,
#         'average': average_score,
#         'top_student': top_student
#     }
# ```
#
# ------------------------------------------------------------
# [3] TEST SUITE
# ------------------------------------------------------------
# ```python
# import pytest
#
# def test_process_students_empty_records():
#     records = []
#     min_score = 50.0
#     result = process_students(records, min_score)
#     assert result == {'filtered': [], 'average': 0.0, 'top_student': None}
#
# def test_process_students_no_score():
#     records = [{'name': 'John', 'age': 20}, {'name': 'Alice', 'age': 22}]
#     min_score = 50.0
#     result = process_students(records, min_score)
#     assert result == {'filtered': [], 'average': 0.0, 'top_student': None}
#
# def test_process_students_no_filtered_records():
#     records = [{'name': 'John', 'score': 40.0}, {'name': 'Alice', 'score': 30.0}]
#     min_score = 50.0
#     result = process_students(records, min_score)
#     assert result == {'filtered': [], 'average': 0.0, 'top_student': None}
#
# def test_process_students_filtered_records():
#     records = [{'name': 'John', 'score': 80.0}, {'name': 'Alice', 'score': 90.0}]
#     min_score = 50.0
#     result = process_students(records, min_score)
#     assert result['filtered'] == [{'name': 'John', 'score': 80.0}, {'name': 'Alice', 'score': 90.0}]
#
# def test_process_students_average_score():
#     records = [{'name': 'John', 'score': 80.0}, {'name': 'Alice', 'score': 90.0}]
#     min_score = 50.0
#     result = process_students(records, min_score)
#     assert result['average'] == (80.0 + 90.0) / 2
# ```
#
# ------------------------------------------------------------
# [4] REVIEW & DOCS
# ------------------------------------------------------------
# * Consider adding input validation for `min_score` to ensure it's a non-negative number.
# * The `top_student` calculation can be simplified using the `max` function with a custom key.
# * The test cases are comprehensive, but consider adding more edge cases, such as an empty `records` list with a non-zero `min_score`.
#
# To run the code, execute the tests using `pytest` with the command `pytest`.

# %% [markdown]
# ---
#
# ## Summary
#
# ### Frameworks Comparison
#
# | | AutoGen | CrewAI |
# |---|---|---|
# | **Abstraction** | Conversational agents | Role-based crew members |
# | **Coordination** | Sequential `initiate_chat()` calls | Declarative `context=[task]` dependencies |
# | **Tools** | `register_function()` | `@tool` decorator |
# | **Best for** | Flexible multi-turn conversations | Structured pipelines with clear handoffs |
# | **Execution** | One conversation at a time | `crew.kickoff()` runs all tasks |
#
# ### Design Patterns We Used
#
# | Pattern | Where we used it |
# |---|---|
# | **Tool Use** | Researcher agent calling `search_internet` |
# | **Planning** | Tasks defined upfront before execution |
# | **Multi-Agent** | Researcher → Writer → Translator pipeline |
# | **Specialization** | Each agent has a distinct role, goal, backstory |
#
# ### Key Takeaways
#
# 1. **Agents are just LLMs + a loop** — the loop adds planning, tool use, and error recovery.
# 2. **Specialization works** — a dedicated Researcher + Writer + Reviewer produces better output than a single all-in-one prompt.
# 3. **Tools are the bridge** to the real world — without tools, agents can only reason; with tools, they can act.
# 4. **The framework is scaffolding** — AutoGen and CrewAI both implement the same core patterns; choose based on your team's preference and the task structure.
#
# ### What's Next
#
# In **Notebook 3** we'll tackle a critical question: *How do you know if your LLM is producing good outputs?* We'll use DeepEval and TruLens to systematically evaluate LLM and RAG system quality — and we'll look at the data, ethics, and security challenges behind these systems.
